# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType
import random
import time
from faker import Faker
from pyspark.sql.functions import *
from datetime import datetime, timedelta

# %%
# Initialize Spark session
spark = SparkSession.builder \
    .appName("Module2Exercise") \
    .config("spark.driver.memory", "512m") \
    .config("spark.executor.memory", "512m") \
    .config("spark.sql.shuffle.partitions", "2") \
    .getOrCreate()
# Out:
# 26/02/08 06:45:46 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
path_data = "../module-3/data_ecommerce_indonesia_1jt"

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("city", StringType(), True),
    StructField("category", StringType(), True),
    StructField("product_name", StringType(), True),
    StructField("price", FloatType(), True)
])

df = spark.read.schema(schema).csv(f"{path_data}").cache()
# Out:
# 26/02/08 06:47:06 WARN CacheManager: Asked to cache already cached data.

# %%
df.rdd.getNumPartitions()
# Out:
# 4

# %%
df = df.repartition(64).cache()  # Repartition to 64 partitions and cache the DataFrame

# %%
df.rdd.getNumPartitions()
# Out:
# [Stage 35:===================================================>    (59 + 4) / 64]
# 64

# %%
# 1. Buktikan kalau Jakarta & Surabaya paling ramai (Realistic Check)
print("--- Top 10 Kota dengan Transaksi Tertinggi ---")
df.groupBy("city").count().orderBy("count", ascending=False).show(10)

# 2. Cek kategori yang paling laku
print("--- Distribusi Kategori Produk ---")
df.groupBy("category").count().orderBy("count", ascending=False).show()

# 3. Intip 5 data terakhir
print("--- Sample 5 Data ---")
df.show(5)
# Out:
# --- Top 10 Kota dengan Transaksi Tertinggi ---
# +---------------+-----+
# |           city|count|
# +---------------+-----+
# |Jakarta Selatan|61488|
# |  Jakarta Barat|61404|
# |  Jakarta Timur|61339|
# |  Jakarta Utara|61278|
# |  Jakarta Pusat|61177|
# |        Bandung|46114|
# |          Medan|46075|
# |       Surabaya|45861|
# |          Batam|37099|
# |         Bekasi|37050|
# +---------------+-----+
# only showing top 10 rows
# --- Distribusi Kategori Produk ---
# +-------------+------+
# |     category| count|
# +-------------+------+
# |    Groceries|357315|
# |   Elektronik|213505|
# |      Fashion|171564|
# |       Health|142400|
# |Home & Living|115181|
# +-------------+------+
#
# --- Sample 5 Data ---
# +------+--------------------+-------------+---------+-----------------+---------+
# |    id|                name|         city| category|     product_name|    price|
# +------+--------------------+-------------+---------+-----------------+---------+
# |948446|     Samsul Palastri|    Tangerang|Groceries| Minyak Goreng 2L|2908490.0|
# |733191|        Salwa Namaga|Jakarta Utara|Groceries|Beras Premium 5kg|1059434.8|
# |231361|Gantar Megantara,...|    Tangerang|   Health|     Minyak Telon|2424948.0|
# |348137|Sutan Vero Narpat...|      Soreang|Groceries|      Susu Steril|2974120.0|
# |331727|       Teddy Santoso|      Bandung|Groceries|   Mie Instan Dus| 992308.4|
# +------+--------------------+-------------+---------+-----------------+---------+
# only showing top 5 rows

# %%
df = df.coalesce(4).cache()  # Coalesce to 4 partitions and cache the DataFrame
df.rdd.getNumPartitions()
# Out:
# [Stage 63:===========================================>              (3 + 1) / 4]
# 4

# %%
# 1. Buktikan kalau Jakarta & Surabaya paling ramai (Realistic Check)
print("--- Top 10 Kota dengan Transaksi Tertinggi ---")
df.groupBy("city").count().orderBy("count", ascending=False).show(10)

# 2. Cek kategori yang paling laku
print("--- Distribusi Kategori Produk ---")
df.groupBy("category").count().orderBy("count", ascending=False).show()

# 3. Intip 5 data terakhir
print("--- Sample 5 Data ---")
df.show(5)
# Out:
# --- Top 10 Kota dengan Transaksi Tertinggi ---
# +---------------+-----+
# |           city|count|
# +---------------+-----+
# |Jakarta Selatan|61488|
# |  Jakarta Barat|61404|
# |  Jakarta Timur|61339|
# |  Jakarta Utara|61278|
# |  Jakarta Pusat|61177|
# |        Bandung|46114|
# |          Medan|46075|
# |       Surabaya|45861|
# |          Batam|37099|
# |         Bekasi|37050|
# +---------------+-----+
# only showing top 10 rows
# --- Distribusi Kategori Produk ---
# +-------------+------+
# |     category| count|
# +-------------+------+
# |    Groceries|357315|
# |   Elektronik|213505|
# |      Fashion|171564|
# |       Health|142400|
# |Home & Living|115181|
# +-------------+------+
#
# --- Sample 5 Data ---
# +------+--------------------+-------------+---------+-----------------+---------+
# |    id|                name|         city| category|     product_name|    price|
# +------+--------------------+-------------+---------+-----------------+---------+
# |948446|     Samsul Palastri|    Tangerang|Groceries| Minyak Goreng 2L|2908490.0|
# |733191|        Salwa Namaga|Jakarta Utara|Groceries|Beras Premium 5kg|1059434.8|
# |231361|Gantar Megantara,...|    Tangerang|   Health|     Minyak Telon|2424948.0|
# |348137|Sutan Vero Narpat...|      Soreang|Groceries|      Susu Steril|2974120.0|
# |331727|       Teddy Santoso|      Bandung|Groceries|   Mie Instan Dus| 992308.4|
# +------+--------------------+-------------+---------+-----------------+---------+
# only showing top 5 rows

# %%
# save df as parquet, name = "data_ecommerce_indonesia_1jt.parquet" partition by city
df.write.mode("overwrite").partitionBy("city").parquet("data_ecommerce_indonesia_1jt-parquet")
# Out:
# 26/02/08 06:57:01 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:01 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:01 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:02 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:03 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:04 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:08 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:09 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:10 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:11 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:11 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:11 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:12 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:12 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:13 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:14 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:17 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:19 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:22 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:26 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers
# 26/02/08 06:57:29 WARN MemoryManager: Total allocation exceeds 95.00% (510,027,360 bytes) of heap memory
# Scaling row group sizes to 95.00% for 4 writers

# %%
# # 1. Setup Spark - Khusus RAM 8GB
# spark = SparkSession.builder \
#     .appName("IndoRealisticGenerator") \
#     .config("spark.driver.memory", "2g") \
#     .config("spark.sql.shuffle.partitions", "1") \
#     .getOrCreate()

# fake = Faker('id_ID')

# # --- CONFIGURATION: REALISTIC CITY DISTRIBUTION ---
# # Meniru pusat ekonomi Indonesia: Jabodetabek, Surabaya, Medan, Makassar, Batam.
# kota_indo = [
#     "Jakarta Selatan", "Jakarta Pusat", "Jakarta Barat", "Jakarta Timur", "Jakarta Utara",
#     "Bandung", "Surabaya", "Medan", "Bekasi", "Tangerang", "Tangerang Selatan", "Depok",
#     "Semarang", "Palembang", "Makassar", "Bogor", "Batam", "Pekanbaru", "Bandar Lampung",
#     "Malang", "Padang", "Denpasar", "Samarinda", "Tasikmalaya", "Serang", "Banjarmasin", "Pontianak",
#     "Cimahi", "Balikpapan", "Jambi", "Surakarta", "Mataram", "Manado", "Yogyakarta", "Cilegon",
#     "Palu", "Kupang", "Ambon", "Tarakan", "Cirebon", "Bengkulu", "Pekalongan", "Kediri", "Tegal",
#     "Binjai", "Pematangsiantar", "Jayapura", "Banda Aceh", "Probolinggo", "Banjarbaru", "Lubuklinggau",
#     "Tanjungpinang", "Batu", "Bitung", "Singkawang", "Pasuruan", "Ternate", "Banjar", "Pangkalpinang",
#     "Lhokseumawe", "Madiun", "Salatiga", "Blitar", "Tanjungbalai", "Langsa", "Palopo", "Metro", 
#     "Tebing Tinggi", "Bontang", "Bima", "Gorontalo", "Pagar Alam", "Bukittinggi", "Parepare",
#     "Bau-Bau", "Gunungsitoli", "Sawahlunto", "Tomohon", "Sabang", "Jatinangor", "Sumedang", "Garut",
#     "Purwakarta", "Subang", "Karawang", "Indramayu", "Majalengka", "Kuningan", "Soreang", "Ngamprah",
#     "Ciamis", "Pangandaran", "Sukabumi", "Cianjur", "Purwokerto", "Kebumen", "Cilacap", "Magelang"
# ]

# # Fungsi pembobotan realistis
# def get_city_weight(city):
#     if "Jakarta" in city: return 20  # Pusat segalanya
#     if city in ["Surabaya", "Medan", "Bandung"]: return 15 # Tier 1
#     if city in ["Bekasi", "Tangerang", "Makassar", "Batam", "Semarang"]: return 12 # Industri & Hub
#     if city in ["Jatinangor", "Palembang", "Depok", "Yogyakarta"]: return 10 # Pendidikan & Regional
#     return 1 # Kota lainnya

# kota_weights = [get_city_weight(k) for k in kota_indo]

# # --- CONFIGURATION: CATEGORIES & PRODUCTS ---
# cat_list = ["Elektronik", "Fashion", "Groceries", "Home & Living", "Health"]
# cat_weights = [15, 12, 25, 8, 10] # Groceries & Elektronik paling tinggi

# product_map = {
#     "Elektronik": ["Smartphone", "Laptop", "Powerbank", "TWS Earbuds", "Smart TV", "Mouse Wireless", "Tablet"],
#     "Fashion": ["Kaos Oversize", "Celana Cargo", "Hoodie", "Sneakers Lokal", "Tas Selempang", "Kemeja Rayon"],
#     "Groceries": ["Beras Premium 5kg", "Minyak Goreng 2L", "Mie Instan Dus", "Susu Steril", "Kopi Kapal Api", "Sabun Cuci Piring"],
#     "Home & Living": ["Air Purifier", "Lampu Pintar", "Sprei Aesthetic", "Tumblr 1L", "Wadah Vacuum", "Rak Sepatu"],
#     "Health": ["Masker KF94", "Vitamin C 1000mg", "Hand Sanitizer", "Minyak Telon", "Sabun Antiseptik", "Madu Murni"]
# }

# schema = StructType([
#     StructField("order_id", IntegerType(), False),
#     StructField("customer_name", StringType(), True),
#     StructField("city", StringType(), True),
#     StructField("category", StringType(), True),
#     StructField("product_name", StringType(), True),
#     StructField("amount", FloatType(), True)
# ])

# # --- EXECUTION: BATCH GENERATION ---
# total_rows = 1000000
# batch_size = 100000
# temp_path = "temp_realistic_ecommerce"

# print(f"🚀 Memulai Generate 1 Juta Baris Data Realistis Indonesia...")
# start_time = time.time()

# for i in range(1, (total_rows // batch_size) + 1):
#     batch_start = (i - 1) * batch_size
#     data_batch = []
    
#     for j in range(batch_size):
#         city = random.choices(kota_indo, weights=kota_weights, k=1)[0]
#         category = random.choices(cat_list, weights=cat_weights, k=1)[0]
#         product = random.choice(product_map[category])
        
#         data_batch.append((
#             batch_start + j,
#             fake.name(),
#             city,
#             category,
#             product,
#             __builtins__.round(random.uniform(10000, 3000000), 2)
#         ))
    
#     df_batch = spark.createDataFrame(data_batch, schema=schema)
#     df_batch.write.mode("append").csv(temp_path, header=(i==1))
#     print(f"✅ Batch {i} selesai. RAM aman.")

# # --- FINAL MERGE TO SINGLE CSV ---
# print("\n📦 Menggabungkan menjadi 1 file CSV...")
# df_final = spark.read.csv(temp_path, header=True, inferSchema=True)
# df_final.coalesce(1).write.mode("overwrite").option("header", "true").csv("data_ecommerce_indonesia_1jt")

# print(f"\n✨ SELESAI dalam {time.time() - start_time:.2f} detik")
# Out:
# 🚀 Memulai Generate 1 Juta Baris Data Realistis Indonesia...
# 26/02/08 06:33:34 WARN TaskSetManager: Stage 0 contains a task of very large size (1044 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 1 selesai. RAM aman.
# 26/02/08 06:33:49 WARN TaskSetManager: Stage 1 contains a task of very large size (1093 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 2 selesai. RAM aman.
# 26/02/08 06:33:59 WARN TaskSetManager: Stage 2 contains a task of very large size (1094 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 3 selesai. RAM aman.
# 26/02/08 06:34:16 WARN TaskSetManager: Stage 3 contains a task of very large size (1093 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 4 selesai. RAM aman.
# 26/02/08 06:34:26 WARN TaskSetManager: Stage 4 contains a task of very large size (1095 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 5 selesai. RAM aman.
# 26/02/08 06:34:37 WARN TaskSetManager: Stage 5 contains a task of very large size (1092 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 6 selesai. RAM aman.
# 26/02/08 06:34:45 WARN TaskSetManager: Stage 6 contains a task of very large size (1095 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 7 selesai. RAM aman.
# 26/02/08 06:34:54 WARN TaskSetManager: Stage 7 contains a task of very large size (1092 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 8 selesai. RAM aman.
# 26/02/08 06:35:10 WARN TaskSetManager: Stage 8 contains a task of very large size (1094 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 9 selesai. RAM aman.
# 26/02/08 06:35:29 WARN TaskSetManager: Stage 9 contains a task of very large size (1094 KiB). The maximum recommended task size is 1000 KiB.
# ✅ Batch 10 selesai. RAM aman.
#
# 📦 Menggabungkan menjadi 1 file CSV...
# 26/02/08 06:35:40 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 224576, Dalima Pratama, Semarang, Groceries, Kopi Kapal Api, 305210.53
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 224576
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-db6bc768-0754-4789-a6d1-52c3a3ee7d1a-c000.csv
# 26/02/08 06:35:40 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 524576, Kenes Wasita, Tasikmalaya, Groceries, Kopi Kapal Api, 213802.64
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 524576
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-e489b829-733a-4fc5-ab13-c35e9e4c470d-c000.csv
# 26/02/08 06:35:40 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 124576, Maria Waluyo, Semarang, Home & Living, Rak Sepatu, 2506122.5
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 124576
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-98c30fa4-6dbd-4093-9ad0-e36274eccc59-c000.csv
# 26/02/08 06:35:40 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 624576, Utama Haryanto, S.Psi, Bandung, Elektronik, Mouse Wireless, 2364244.0
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 624576
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-a18dda62-05aa-4432-a4f8-4386831651ce-c000.csv
# 26/02/08 06:35:40 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 924576, Maya Fujiati, Makassar, Groceries, Sabun Cuci Piring, 2379687.8
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 924576
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-0edd54ed-d0af-4924-b12b-647db77c2c7c-c000.csv
# 26/02/08 06:35:40 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 724576, Mitra Rajata, Yogyakarta, Fashion, Hoodie, 2940117.0
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 724576
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-49ce4ebb-6104-478a-b88e-2f851a42b4ab-c000.csv
# 26/02/08 06:35:41 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 424576, Harsaya Habibi, Yogyakarta, Groceries, Mie Instan Dus, 547332.2
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 424576
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-60088c06-5ffa-4588-b5c0-36b2d7907269-c000.csv
# 26/02/08 06:35:41 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 324576, dr. Lala Yulianti, Depok, Health, Hand Sanitizer, 652414.3
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 324576
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-f3fd2ca0-a152-4d2c-82c2-b66b948bee42-c000.csv
# 26/02/08 06:35:41 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 274752, Ade Suryatmi, Makassar, Groceries, Mie Instan Dus, 1009824.1
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 274752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-db6bc768-0754-4789-a6d1-52c3a3ee7d1a-c000.csv
# 26/02/08 06:35:41 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 574752, Lanjar Haryanti, S.Sos, Tegal, Groceries, Minyak Goreng 2L, 1873368.9
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 574752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-e489b829-733a-4fc5-ab13-c35e9e4c470d-c000.csv
# 26/02/08 06:35:42 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 174752, Tgk. Ilsa Prasetyo, Jakarta Timur, Fashion, Sneakers Lokal, 2728312.0
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 174752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-98c30fa4-6dbd-4093-9ad0-e36274eccc59-c000.csv
# 26/02/08 06:35:42 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 774752, Jagaraga Marpaung, Tangerang, Elektronik, TWS Earbuds, 189531.56
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 774752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-49ce4ebb-6104-478a-b88e-2f851a42b4ab-c000.csv
# 26/02/08 06:35:42 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 974752, Puspa Hidayanto, S.Sos, Tangerang, Groceries, Susu Steril, 127729.28
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 974752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-0edd54ed-d0af-4924-b12b-647db77c2c7c-c000.csv
# 26/02/08 06:35:42 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 474752, Samiah Andriani, Jakarta Utara, Elektronik, Smart TV, 301037.94
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 474752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-60088c06-5ffa-4588-b5c0-36b2d7907269-c000.csv
# 26/02/08 06:35:42 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 674752, Laila Ardianto, Bekasi, Groceries, Sabun Cuci Piring, 31363.29
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 674752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-a18dda62-05aa-4432-a4f8-4386831651ce-c000.csv
# 26/02/08 06:35:42 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: order_id, customer_name, city, category, product_name, amount
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: order_id
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00001-8e1ee1d0-f058-4bc8-ab90-807d06233345-c000.csv
# 26/02/08 06:35:43 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 874752, Mahfud Yulianti, Jatinangor, Fashion, Sneakers Lokal, 1431557.8
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 874752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-5c6f6679-6270-4888-859d-bcbdcbe902bf-c000.csv
# 26/02/08 06:35:43 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 374752, Bakti Putra, M.Ak, Blitar, Groceries, Susu Steril, 602686.75
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 374752
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-f3fd2ca0-a152-4d2c-82c2-b66b948bee42-c000.csv
# 26/02/08 06:35:43 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: order_id, customer_name, city, category, product_name, amount
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: order_id
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00003-8e1ee1d0-f058-4bc8-ab90-807d06233345-c000.csv
# 26/02/08 06:35:43 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 800000, Putu Wasita, Jakarta Timur, Health, Masker KF94, 412118.8
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 800000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-5c6f6679-6270-4888-859d-bcbdcbe902bf-c000.csv
# 26/02/08 06:35:43 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 900000, Puti Icha Narpati, Bandung, Home & Living, Sprei Aesthetic, 1930021.2
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 900000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-0edd54ed-d0af-4924-b12b-647db77c2c7c-c000.csv
# 26/02/08 06:35:44 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 750176, Kenzie Kuswoyo, Palopo, Fashion, Celana Cargo, 467420.34
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 750176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-49ce4ebb-6104-478a-b88e-2f851a42b4ab-c000.csv
# 26/02/08 06:35:44 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 600000, drg. Elisa Rahmawati, Palopo, Elektronik, Powerbank, 2437693.5
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 600000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-a18dda62-05aa-4432-a4f8-4386831651ce-c000.csv
# 26/02/08 06:35:44 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 550176, dr. Gabriella Palastri, Palembang, Elektronik, Powerbank, 1409992.6
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 550176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-e489b829-733a-4fc5-ab13-c35e9e4c470d-c000.csv
# 26/02/08 06:35:44 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 200000, Tina Permata, Sukabumi, Fashion, Kemeja Rayon, 1325766.1
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 200000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-db6bc768-0754-4789-a6d1-52c3a3ee7d1a-c000.csv
# 26/02/08 06:35:44 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 350176, Jail Pratama, Makassar, Elektronik, Powerbank, 175757.92
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 350176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-f3fd2ca0-a152-4d2c-82c2-b66b948bee42-c000.csv
# 26/02/08 06:35:45 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 100000, Budi Saragih, Surabaya, Elektronik, Laptop, 2628586.0
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 100000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-98c30fa4-6dbd-4093-9ad0-e36274eccc59-c000.csv
# 26/02/08 06:35:45 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 950176, Sutan Hadi Hassanah, M.Pd, Bengkulu, Fashion, Kemeja Rayon, 35156.56
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 950176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-0edd54ed-d0af-4924-b12b-647db77c2c7c-c000.csv
# 26/02/08 06:35:45 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 850176, Janet Yuniar, Jayapura, Groceries, Beras Premium 5kg, 638651.75
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 850176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-5c6f6679-6270-4888-859d-bcbdcbe902bf-c000.csv
# 26/02/08 06:35:45 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 250176, Kayun Permadi, S.Farm, Medan, Elektronik, TWS Earbuds, 2581119.5
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 250176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-db6bc768-0754-4789-a6d1-52c3a3ee7d1a-c000.csv
# 26/02/08 06:35:46 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 400000, Uda Hutasoit, S.E.I, Bekasi, Health, Masker KF94, 416553.66
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 400000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-60088c06-5ffa-4588-b5c0-36b2d7907269-c000.csv
# 26/02/08 06:35:48 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 650176, Chandra Megantara, Depok, Groceries, Susu Steril, 1388174.9
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 650176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-a18dda62-05aa-4432-a4f8-4386831651ce-c000.csv
# 26/02/08 06:35:49 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 450176, Dacin Astuti, Jakarta Timur, Groceries, Minyak Goreng 2L, 1050336.6
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 450176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-60088c06-5ffa-4588-b5c0-36b2d7907269-c000.csv
# 26/02/08 06:35:49 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 150176, Cut Sabrina Purnawati, Tangerang, Groceries, Mie Instan Dus, 251838.88
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 150176
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-98c30fa4-6dbd-4093-9ad0-e36274eccc59-c000.csv
# 26/02/08 06:35:49 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 500000, Estiawan Napitupulu, S.Pd, Ciamis, Groceries, Sabun Cuci Piring, 1108574.2
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 500000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-e489b829-733a-4fc5-ab13-c35e9e4c470d-c000.csv
# 26/02/08 06:35:50 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 700000, Zizi Yulianti, Medan, Elektronik, Laptop, 266006.8
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 700000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-49ce4ebb-6104-478a-b88e-2f851a42b4ab-c000.csv
# 26/02/08 06:35:50 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 300000, Kenari Marbun, Jakarta Timur, Fashion, Hoodie, 2598874.0
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: 300000
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-f3fd2ca0-a152-4d2c-82c2-b66b948bee42-c000.csv
# 26/02/08 06:35:50 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: order_id, customer_name, city, category, product_name, amount
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: order_id
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00002-8e1ee1d0-f058-4bc8-ab90-807d06233345-c000.csv
# 26/02/08 06:35:51 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: order_id, customer_name, city, category, product_name, amount
#  Schema: 824576, Wasis Narpati, Jayapura, Elektronik, TWS Earbuds, 1352703.9
# Expected: 824576 but found: order_id
# CSV file: file:///home/sanju3291/DATA-ENGINEER/03-tools-and-setup/technology-stack/06-spark-processing/notebooks/module-3/temp_realistic_ecommerce/part-00000-8e1ee1d0-f058-4bc8-ab90-807d06233345-c000.csv
# ✨ SELESAI dalam 160.54 detik
